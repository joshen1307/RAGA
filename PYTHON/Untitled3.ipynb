# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
ls -tr
# Out:
# MiraBest.py                         untitled3.txt
# FRDEEP.py                           out.out
# README.md                           out2.out
# VAE.py                              genetic_algo.py
# VAE_example.ipynb                   untitled2.txt
# FIRST_data/                         VAE_FIRST_NON_GPU_Conf2_0_v1.py
# VAE_FRI_AND_FRII_FIRST.ipynb        out3.out
# VAE_FIRST_UNSUPERVISED.ipynb        Untitled1.ipynb
# VAE_MNIST_PYRO_NON_GPU_v1.ipynb     Untitled2.ipynb
# fr1_sample_z_space_49.png           output.out
# VAE_MNIST_FIRST_NON_GPU_v1.ipynb    out5.out
# fr2_sample_z_space_2999.png         out4.out
# fr1_sample_z_space_2999.png         out10.out
# fr2_sample_z_space_999.png          out11.out
# fr1_sample_z_space_999.png          out16.out
# VAE_FIRST_NON_GPU_Conf2_0_v1.ipynb  0ut20.out
# untitled.txt                        0ut21.out
# ga.py                               genetic_algo_sVAE_FIRST_MIRABEST_CONFXX.py
# Untitled.ipynb                      untitled4.txt
# ...

# %%
data=pd.read_csv('experiment_1_2.csv',delimiter = ' ')

# %%
data['h_dim_enco_1'][data['chromosome']==1]
# Out:
# 0      591
# 8     1015
# 16     945
# 24     655
# 32     973
# 40    1163
# 48    1163
# 56    1214
# 64    1150
# 72    1173
# 80    1172
# 88    1186
# Name: h_dim_enco_1, dtype: int64

# %%
data['gen'][data['chromosome']==1]
# Out:
# 0      1
# 8      2
# 16     3
# 24     4
# 32     5
# 40     6
# 48     7
# 56     8
# 64     9
# 72    10
# 80    11
# 88    12
# Name: gen, dtype: int64

# %%
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==1],label='Chromosome 1')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==2],label='Chromosome 2')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==3],label='Chromosome 3')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==4],label='Chromosome 4')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==5],label='Chromosome 5')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==6],label='Chromosome 6')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==7],label='Chromosome 7')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_1'][data['chromosome']==8],label='Chromosome 8')
plt.legend()
plt.xlabel('Generation')
plt.ylabel('# Nodes 1st Encoder')
# Out:
# Text(0, 0.5, '# Nodes 1st Encoder')

# %%
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==1],label='Chromosome 1')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==2],label='Chromosome 2')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==3],label='Chromosome 3')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==4],label='Chromosome 4')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==5],label='Chromosome 5')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==6],label='Chromosome 6')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==7],label='Chromosome 7')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_enco_2'][data['chromosome']==8],label='Chromosome 8')
plt.legend()
plt.xlabel('Generation')
plt.ylabel('# Nodes 2nd Encoder')
# Out:
# Text(0, 0.5, '# Nodes 2nd Encoder')

# %%
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==1],label='Chromosome 1')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==2],label='Chromosome 2')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==3],label='Chromosome 3')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==4],label='Chromosome 4')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==5],label='Chromosome 5')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==6],label='Chromosome 6')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==7],label='Chromosome 7')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_1'][data['chromosome']==8],label='Chromosome 8')
plt.legend()
plt.xlabel('Generation')
plt.ylabel('# Nodes 1st Decoder')
# Out:
# Text(0, 0.5, '# Nodes 1st Decoder')

# %%
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==1],label='Chromosome 1')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==2],label='Chromosome 2')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==3],label='Chromosome 3')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==4],label='Chromosome 4')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==5],label='Chromosome 5')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==6],label='Chromosome 6')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==7],label='Chromosome 7')
plt.plot(data['gen'][data['chromosome']==1],data['h_dim_deco_2'][data['chromosome']==8],label='Chromosome 8')
plt.legend()
plt.xlabel('Generation')
plt.ylabel('# Nodes 2nd Decoder')
# Out:
# Text(0, 0.5, '# Nodes 2nd Decoder')

# %%
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==1],label='Chromosome 1')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==2],label='Chromosome 2')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==3],label='Chromosome 3')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==4],label='Chromosome 4')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==5],label='Chromosome 5')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==6],label='Chromosome 6')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==7],label='Chromosome 7')
plt.plot(data['gen'][data['chromosome']==1],data['test_loss'][data['chromosome']==8],label='Chromosome 8')
plt.legend()
plt.xlabel('Generation')
plt.ylabel('Test Loss')
# Out:
# Text(0, 0.5, 'Test Loss')

# %%
data
# Out:
#     h_dim_enco_1  h_dim_enco_2  h_dim_deco_1  h_dim_deco_2  train_loss  \
# 0            591           447           359           530    301.7507
# 1            622           407           666           797    276.7101
# 2            231           105           806           951    286.9132
# 3            832           642           985           997    267.6192
# 4            869           753           714           882    278.1717
# ..           ...           ...           ...           ...         ...
# 67           710           520           985           997    267.7330
# 68           716           526           985           997    267.0935
# 69           712           522           728           772    275.8824
# 70           912           722           912           988    270.2024
# 71           912           722           976          1180    268.0720
#
#     test_loss  chromosome  gen
# 0    314.1319           1    1
# 1    288.5836           2    1
# ...
